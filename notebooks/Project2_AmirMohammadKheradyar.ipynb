# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploratory Data Analysis

# %%
df = pd.read_excel('../data/Dry_Bean_Dataset.xlsx')

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %% [markdown]
# According to the above information, there are not any missing value in our dataset. Also, all of our feature are numerical.

# %%
df['Class'] = df['Class'].astype(dtype='category')

# %% [markdown]
# Switching the `Class` parameter from **object** to **category** would help reduce the dataset's memory usage.

# %%
df = df.drop_duplicates()

# %%
df.reset_index(drop="True")
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13538  42097    759.696       288.721612       185.944705      1.552728
# 13539  42101    757.499       281.576392       190.713136      1.476439
# 13540  42139    759.321       281.539928       191.187979      1.472582
# 13541  42147    763.779       283.382636       190.275731      1.489326
# 13542  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %% [markdown]
# As you can see, there were 68 rows of duplicate data.

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13543.000000  13543.000000     13543.000000     13543.000000
# mean    53048.460385    854.993406       319.895602       202.365321
# std     29392.438324    214.722684        85.809260        45.051632
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36282.500000    703.230000       253.086806       175.886357
# 50%     44580.000000    793.896000       296.404589       192.491117
# 75%     61382.000000    977.146500       376.312489       217.245403
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13543.000000  13543.000000   13543.000000   13543.000000  13543.000000
# mean       1.581075      0.750315   53767.986709     253.034094      0.749829
# std        0.245245      0.091858   29844.248525      59.307709      0.048939
# ...

# %%
df.drop('Class', axis=1).corr()
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966908         0.932623         0.952041
# Perimeter        0.966908   1.000000         0.977561         0.914336
# MajorAxisLength  0.932623   0.977561         1.000000         0.828360
# MinorAxisLength  0.952041   0.914336         0.828360         1.000000
# AspectRation     0.243698   0.386097         0.550075        -0.005354
# Eccentricity     0.268580   0.391062         0.541011         0.022391
# ConvexArea       0.999940   0.967871         0.933392         0.951780
# EquivDiameter    0.984998   0.991453         0.962271         0.949214
# Extent           0.054648  -0.020620        -0.077287         0.145906
# Solidity        -0.197333  -0.304662        -0.284857        -0.156819
# roundness       -0.359068  -0.548336        -0.595710        -0.214090
# Compactness     -0.269797  -0.407426        -0.567902        -0.018618
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.drop('Class', axis=1).corr(), annot=True);

# %%
classes = df['Class'].value_counts()
classes
# Out:
# Class
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1860
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: count, dtype: int64

# %% [markdown]
# We have 7 types of dry beans but the categories exhibit an **imbalance** in distribution.

# %%
plt.figure()
sns.barplot(x=classes.index, y=classes.values, hue=classes.index);
plt.xlabel("Classes");
plt.ylabel("Count");
plt.title("No. data per class");

# %%
plt.figure()
plt.pie(classes.values,labels=classes.index, autopct='%1.2f%%');
plt.title("Percentage of each class");

# %% [markdown]
# There are the most instances of the `DERMASON` type and the fewest instances of the `BOMBAY` type.

# %%
df.hist(figsize=(14, 10), bins=30);

# %% [markdown]
# ### [Additional Variable Information (From paper)](../Multiclass_classification_of_dry_beans_using_computer_vision_and.pdf)

# %% [markdown]
# ## Features

# %% [markdown]
# <b>Area (A)</b>: The area of a bean zone and the number of pixels within its boundaries.
#
# <b>Perimeter (P)</b>: Bean circumference is defined as the length of its border.
#
# <b>Major axis length (L)</b>: The distance between the ends of the longest line that can be drawn from a bean.
#
# <b>Minor axis length (l)</b>: The longest line that can be drawn from the bean while standing perpendicular to the main axis.
#
# <b>Aspect ratio (K)</b>: Defines the relationship between L and l.
#
# $$ K = \frac{L}{l} $$
#
# <b>Eccentricity (Ec)</b>: Eccentricity of the ellipse having the same moments as the region.
#
# <b>Convex area (C)</b>: Number of pixels in the smallest convex polygon that can contain the area of a bean seed.
#
# <b>Equivalent diameter (Ed)</b>: The diameter of a circle having the same area as a bean seed area.
#
# $$ d = \sqrt{\frac{4 * A}{\pi}} $$
#
# <b>Extent (Ex)</b>: The ratio of the pixels in the bounding box to the bean area.
#
# $$Ex = \frac{A}{A_{B}}$$
#
# Where <i>A<sub>B</sub></i> is the area of bounding rectangle.
#
# <b>Solidity (S)</b>: Also known as convexity. The ratio of the pixels in the convex shell to those found in beans.
#
# $$ S = \frac{A}{C} $$
#
# <b>Roundness (R)</b>: Calculated with the following formula:
#
# $$ R = \frac{4 * \pi * A}{P^{2}} $$
#
# <b>Compactness (CO)</b>: Measures the roundness of an object:
#
# $$ CO = \frac{Ed}{L} $$
#
# <b>The shape features used in the classification of the bean seeds are as follows:</b>
#
# $$ShapeFactor1 (SF1) = \frac{L}{A}$$
#
# $$ ShapeFactor2 (SF2) = \frac{l}{A} $$
#
# $$ ShapeFactor3 (SF3) = \frac{A}{\frac{L}{2} * \frac{L}{2} * \pi} $$
#
# $$ ShapeFactor4 (SF4) = \frac{A}{\frac{L}{2} * \frac{l}{2} * \pi} $$

# %% [markdown]
# ## Label

# %% [markdown]
# <b>Class: </b>

# %% [markdown]
# <img src="../Fig_1.png">

# %% [markdown]
# # Preprocessing

# %%
X = df.drop('Class', axis=1) 
y = df['Class']

# %%
from sklearn.preprocessing import LabelEncoder

li = LabelEncoder()
y_new = li.fit_transform(y)
list(enumerate(li.classes_))
# Out:
# [(0, 'BARBUNYA'),
#  (1, 'BOMBAY'),
#  (2, 'CALI'),
#  (3, 'DERMASON'),
#  (4, 'HOROZ'),
#  (5, 'SEKER'),
#  (6, 'SIRA')]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
                                    X, y_new, test_size=0.2, random_state=42, stratify=y_new)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

dt_model = DecisionTreeClassifier(random_state=42, class_weight='balanced')

h_params = {'criterion': ["gini", "log_loss", "entropy"], 
            'max_depth':[7, 8, 9],
            'min_samples_split': [3, 4, 5]}

grid_cv = GridSearchCV(estimator=dt_model, cv=5, param_grid=h_params, scoring='accuracy')
grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=DecisionTreeClassifier(class_weight='balanced',
#                                               random_state=42),
#              param_grid={'criterion': ['gini', 'log_loss', 'entropy'],
#                          'max_depth': [7, 8, 9],
#                          'min_samples_split': [3, 4, 5]},
#              scoring='accuracy')

# %%
grid_cv.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 3}

# %% [markdown]
# We found the best values for the hyperparameters through the above process.

# %%
best_dt_model = grid_cv.best_estimator_
best_dt_model
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=8,
#                        min_samples_split=3, random_state=42)

# %%
grid_cv.best_score_
# Out:
# 0.909913752880976

# %% [markdown]
# The mean cross-validated score of the best estimator is about 0.90.

# %%
best_dt_model.score(X_test, y_test)
# Out:
# 0.9036544850498339

# %% [markdown]
# The mean accuracy score for the testing set is roughly 0.90.

# %%
best_dt_model.score(X_train, y_train)
# Out:
# 0.933357947203249

# %% [markdown]
# The mean accuracy score for the training set is roughly 0.93.

# %%
from sklearn.metrics import confusion_matrix

y_pred = best_dt_model.predict(X_test)
cm_dt = confusion_matrix(y_test, y_pred)

classes = np.array(list(enumerate(li.classes_)))

plt.figure(figsize=(10, 6))
sns.heatmap(cm_dt, annot=True, fmt="d", linewidths=0.5);
plt.xticks(np.int32(classes[:,0]),classes[:,1],rotation=45,minor=True);
plt.yticks(np.int32(classes[:,0]),classes[:,1],rotation=45,minor=True);

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=li.classes_, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#     BARBUNYA    0.89394   0.89057   0.89225       265
#       BOMBAY    1.00000   1.00000   1.00000       104
#         CALI    0.88304   0.92638   0.90419       326
#     DERMASON    0.91404   0.89986   0.90689       709
#        HOROZ    0.94678   0.90860   0.92730       372
#        SEKER    0.92067   0.94335   0.93187       406
#         SIRA    0.84659   0.84820   0.84739       527
#
#     accuracy                        0.90365      2709
#    macro avg    0.91501   0.91671   0.91570      2709
# weighted avg    0.90401   0.90365   0.90368      2709

# %% [markdown]
# The results indicate that the model fits the data well, meaning it performs effectively.

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

rf_model = RandomForestClassifier(random_state=42, class_weight='balanced', n_estimators=150)
h_params = {
            'max_depth':[7, 8, 9],
            'min_samples_split': [2, 3, 4]}

grid_cv = GridSearchCV(estimator=rf_model, cv=5, param_grid=h_params, scoring='accuracy')
grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               n_estimators=150,
#                                               random_state=42),
#              param_grid={'max_depth': [7, 8, 9],
#                          'min_samples_split': [2, 3, 4]},
#              scoring='accuracy')

# %%
grid_cv.best_params_
# Out:
# {'max_depth': 9, 'min_samples_split': 3}

# %% [markdown]
# We found the best values for the hyperparameters through the above process.

# %%
best_rf_model = grid_cv.best_estimator_
best_rf_model
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=9,
#                        min_samples_split=3, n_estimators=150, random_state=42)

# %%
grid_cv.best_score_
# Out:
# 0.920805152073344

# %% [markdown]
# Random Forest model as an ensemble method has proven more effective in enhancing results (0.92) compared to the decision tree model (0.90).

# %%
best_rf_model.score(X_test, y_test)
# Out:
# 0.9147286821705426

# %% [markdown]
# The mean accuracy score for the testing set is roughly 0.91.

# %%
best_rf_model.score(X_train, y_train)
# Out:
# 0.944341886653129

# %% [markdown]
# The mean accuracy score for the training set is roughly 0.94.

# %%
from sklearn.metrics import confusion_matrix

y_pred = best_rf_model.predict(X_test)
cm_dt = confusion_matrix(y_test, y_pred)

classes = np.array(list(enumerate(li.classes_)))

plt.figure(figsize=(10, 6))
sns.heatmap(cm_dt, annot=True, fmt="d", linewidths=0.5);
plt.xticks(np.int32(classes[:,0]),classes[:,1],rotation=45,minor=True);
plt.yticks(np.int32(classes[:,0]),classes[:,1],rotation=45,minor=True);

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=li.classes_, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#     BARBUNYA    0.92913   0.89057   0.90944       265
#       BOMBAY    1.00000   1.00000   1.00000       104
#         CALI    0.91343   0.93865   0.92587       326
#     DERMASON    0.91691   0.90268   0.90974       709
#        HOROZ    0.96685   0.94086   0.95368       372
#        SEKER    0.92086   0.94581   0.93317       406
#         SIRA    0.84972   0.86907   0.85929       527
#
#     accuracy                        0.91473      2709
#    macro avg    0.92813   0.92681   0.92731      2709
# weighted avg    0.91526   0.91473   0.91485      2709

# %% [markdown]
# The results are promising, but they also suggest that the Random Forest model may have a tendency to overfit.

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

svc_model = SVC(random_state=42)
h_params = {'C': [0.01, 0.1, 1, 10, 100], 
            'kernel':["linear", "poly", "rbf", "sigmoid"],
            'degree': [2, 3, 5]}

grid_cv = GridSearchCV(estimator=svc_model, cv=5, param_grid=h_params, scoring='accuracy')
grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(random_state=42),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100], 'degree': [2, 3, 5],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='accuracy')

# %%
grid_cv.best_params_
# Out:
# {'C': 100, 'degree': 2, 'kernel': 'rbf'}

# %% [markdown]
# We found the best values for the hyperparameters through the above process.

# %%
best_svc_model = grid_cv.best_estimator_
best_svc_model
# Out:
# SVC(C=100, degree=2, random_state=42)

# %%
grid_cv.best_score_
# Out:
# 0.9326199122998764

# %% [markdown]
# The mean cross-validated score of the best estimator is about 0.93 and it shows our SVC model has better model than Random Forest (0.92) or Decision Tree (0.90) in this dataset.

# %%
best_svc_model.score(X_test, y_test)
# Out:
# 0.9228497600590624

# %% [markdown]
# The mean accuracy score for the testing set is roughly 0.92!

# %%
best_svc_model.score(X_train, y_train)
# Out:
# 0.9459110208602548

# %% [markdown]
# The mean accuracy score for the training set is roughly 0.94.

# %%
from sklearn.metrics import confusion_matrix

y_pred = best_svc_model.predict(X_test)
cm_dt = confusion_matrix(y_test, y_pred)

classes = np.array(list(enumerate(li.classes_)))

plt.figure(figsize=(10, 6))
sns.heatmap(cm_dt, annot=True, fmt="d", linewidths=0.5);
plt.xticks(np.int32(classes[:,0]),classes[:,1],rotation=45,minor=True);
plt.yticks(np.int32(classes[:,0]),classes[:,1],rotation=45,minor=True);

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=li.classes_, digits=5))
# Out:
#               precision    recall  f1-score   support
#
#     BARBUNYA    0.91698   0.91698   0.91698       265
#       BOMBAY    1.00000   1.00000   1.00000       104
#         CALI    0.92771   0.94479   0.93617       326
#     DERMASON    0.90997   0.92666   0.91824       709
#        HOROZ    0.97199   0.93280   0.95199       372
#        SEKER    0.94146   0.95074   0.94608       406
#         SIRA    0.87669   0.86338   0.86998       527
#
#     accuracy                        0.92285      2709
#    macro avg    0.93497   0.93362   0.93421      2709
# weighted avg    0.92301   0.92285   0.92283      2709

# %% [markdown]
# With the highest accuracy among all models, the SVC (Support Vector Classification) model emerges as an excellent choice for effectively classifying different types of dry beans.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this project, our goal was to train multiple machine learning models to find the best model for categorizing dry beans. Our task was a classification, and we modeled three algorithms: RF, DT, and SVC. We found that overall, these three algorithms performed well for our task, but our SVC model demonstrated the best performance and results. You can see the results of each model in the table below.

# %% [markdown]
# <table>
#     <tr>
#         <td><b>Model</b></td>
#         <td><b>Best Score</b></td>
#         <td><b>Train Accuracy Score</b></td>
#         <td><b>Test Accuracy Score</b></td>
#     </tr>
#     <tr>
#         <td>DT</td>
#         <td>0.9099</td>
#         <td>0.9333</td>
#         <td>0.9036</td>
#     </tr>
#     <tr>
#         <td>RF</td>
#         <td>0.9208</td>
#         <td>0.9443</td>
#         <td>0.9147</td>
#     </tr>
#     <tr>
#         <td>SVC</td>
#         <td>0.9326</td>
#         <td>0.9459</td>
#         <td><font color = '#FFD700'><b>0.9228</b></td>
#     </tr>
# </table>

# %% [markdown]
# During this project, I encountered new topics in learning. For example, I found that I had to split the data before normalization to avoid data leakage. In addition, I had a long process of fine-tuning my models to achieve the best performance. I noticed that the parameters are not on their edge...

# %% [markdown]
# # Thanks for everything!

# %% [markdown]
# ### AmirMohammad Kheradyar
